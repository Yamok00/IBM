# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ### YUNUS MUHIDEEN ORIYOMI
# Data Scientist

# %% [markdown]
# _I am interested in data science because I think it's a very cool job_

# %% [markdown]
# ### The code in the next cells gives the sum of two numbers

# %%
4 + 4
# Out:
# 8

# %% [markdown]
# | Hello | Hi | Trial |
# | --- | --- | --- |
# | IBM | Google | Amazon |
#
#
# 1. Line 1
# 2. Line 2
# 3. Line 3
#
# [google](google.com)
